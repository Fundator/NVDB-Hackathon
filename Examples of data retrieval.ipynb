# %% [markdown]
# ![headerimage](https://github.com/Fundator/NVDB-Hackathon/blob/master/imgs/front.png?raw=true)
#
# # Examples of retrieving data from several sources
# This is a short tutorial on how to download your own data from nvdb. It is written in python, but using HTTP-requests in other languages should follow the same principles.

# %% [markdown]
# # NVDB

# %% [markdown]
# ## Read the docs
# The API documentation for NVDB can be found [here](https://www.vegvesen.no/nvdb/apidokumentasjon/)

# %% [markdown]
# ## Python-wrapper for NVDB, pnvdb
# Github user Acurus has made a python-wrapper for NVDB. It can be found [here](https://github.com/Acurus/pnvdb)

# %% [markdown]
# ## Necessary packages

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ## List all types of road objects (vegobjekter)

# %%
url = "https://www.vegvesen.no/nvdb/api/v2/vegobjekter"
r = requests.get(url)
vegobjekter = json.loads(r.content)

# %%
df = pd.DataFrame(vegobjekter)
df["id"] = df["href"].apply(lambda x: x.split("/")[-1])

# %%
df

# %% [markdown]
# ## Get list of ID's of specific road object type

# %% [markdown]
# List of object ids can be seen [here](https://datakatalogen.vegdata.no/)

# %%
objektid = 25 #  Leskur
url = f"https://www.vegvesen.no/nvdb/api/v2/vegobjekter/{objektid}"
r = requests.get(url)
vegobjekt = json.loads(r.content)

# %%
vegobjekt

# %% [markdown]
# ## Pagination, get large amounts of data
# nvdb API has a limit of 1000 returned values per request. However, it has a handy paginationfunction to download higher amount of content. If we inspect the metadata part of the latest request, we can see that it includes an url to the next content

# %%
vegobjekt["metadata"]

# %% [markdown]
# Lets get the next 1000 objects

# %%
r = requests.get(vegobjekt["metadata"]["neste"]["href"])
next_1000 = json.loads(r.content)

# %%
next_1000

# %% [markdown]
# ## Acessing a specific road object

# %%
index = 0
url = next_1000["objekter"][index]["href"]
r = requests.get(url)
objekt = json.loads(r.content)

# %%
objekt

# %% [markdown]
# ## Specifying and restricting the search
# NVDB-API has several parameters to specify where to get data, for example
#
# - Karutsnitt (rectangular map)
# - Fylke / Kommune (Region / Municipality)
# - Kontraktsområde
#
# More information can be found on the [API-documentation page](https://www.vegvesen.no/nvdb/apidokumentasjon/#/)

# %% [markdown]
# ### Example, get all toll booths in trondheim

# %%
vegobjid = 45  #  Toll booths
kommuneid = 5001  #  Trondheim
url = f"https://www.vegvesen.no/nvdb/api/v2/vegobjekter/{vegobjid}?kommune={kommuneid}"
r = requests.get(url)
toll_booths_trd = json.loads(r.content)
toll_booths_trd

# %% [markdown]
# ### Lets check one of the toll booths in trondheim

# %%
index = 0
example_toll_booth_url = toll_booths_trd["objekter"][index]["href"]
r = requests.get(example_toll_booth_url)
json.loads(r.content)

# %% [markdown]
# ## Geospatial data in NVDB
# Road objects in NVDB is described mostly using UTM33N.

# %%
geometri = objekt["geometri"]
geometri

# %% [markdown]
# ##  <font color=green>Tips & tricks<font>

# %% [markdown]
# ## Using geodaisy to parse WKT
# For most WKT-types, with the exception of some geometry-types, like LINESTRING Z, geodaisy is one of the most lightweight libraries for parsing wkt

# %%
import geodaisy.converters as convert

# %%
geo = convert.wkt_to_geo_interface(geometri["wkt"])
geo

# %%
easting, northing = geo["coordinates"]

# %% [markdown]
# ## Converting UTM to lat-long
# For some applications like google maps api, lat-long is the only accepted geo-description. **UTM** is an easy-to-use library for python for converting  between UTM and lat-long. <font color=red>Some geometries may exceed the northing / easting ranges<font>

# %%
import utm

# %%
lat, lon = utm.to_latlon(easting, northing, zone_number=33, northern=True, strict=False)

# %%
lat, lon

# %% [markdown]
# # Air Quality data from NILU
# NILU offers historical and live air quality data from all of Norway.

# %% [markdown]
# ## List of components
# Components are different parameters measured by the sensors, such as CO, NO2. All components avaliable can be found by the following request

# %%
url = "https://api.nilu.no/lookup/components"
r = requests.get(url)
comp = json.loads(r.content)
pd.DataFrame(comp)

# %% [markdown]
# ## Get the latest values for all components for all stations in Trondheim

# %%
components = [i["component"] for i in comp]
compstr = ";".join(components)
url = f"https://api.nilu.no/aq/utd?areas=trondheim&components={compstr}"
r = requests.get(url)
val = json.loads(r.content)
pd.DataFrame(val)

# %%
url = f"https://api.nilu.no/obs/utd?areas=trondheim&components={compstr}"
r = requests.get(url)
val = json.loads(r.content)
pd.DataFrame(val)

# %% [markdown]
# ## Find all stations in Trondheim

# %%
url = f"https://api.nilu.no/lookup/stations?area=trondheim"
r = requests.get(url)
val = json.loads(r.content)
stations = pd.DataFrame(val)
stations

# %%
stations = stations["station"].tolist()
months = pd.date_range("2015-01-01", "2019-08-01", freq="m")
months = [str(m).split(" ")[0] for m in months]

# %% [markdown]
# ## Get observations from last 3 years

# %%
l = []
for station in stations:
    fromdate = months[0]
    for todate in months[1:]:
        url = f"https://api.nilu.no/obs/historical/{fromdate}/{todate}/{station}/?components={compstr}"
        r = requests.get(url)
        val = json.loads(r.content)
        l.append(val)
        fromdate = todate

# %%
d = pd.DataFrame()
for i in range(len(l)):
    d = d.append(pd.DataFrame(l[i]))

# %%
j =  []
columns = d.drop(columns="values").columns.tolist()
for i in range(d.shape[0]):
    leftside = pd.DataFrame(d.iloc[i]).T
    rightside = pd.DataFrame(d.iloc[i]["values"])
    for c in columns:
        rightside.loc[:,c] = leftside[c].values
    j.append(rightside)

# %%
dj = pd.concat(j)
dj.to_csv("airquality_observations_2015_2019.csv")

# %% [markdown]
# ## Get air quality index from last 3 years

# %%
l = []
for station in stations:
    fromdate = months[0]
    for todate in months[1:]:
        url = f"https://api.nilu.no/aq/historical/{fromdate}/{todate}/{station}/?components={compstr}"
        r = requests.get(url)
        val = json.loads(r.content)
        l.append(val)
        fromdate = todate

# %%
d = pd.DataFrame()
for i in range(len(l)):
    d = d.append(pd.DataFrame(l[i]))

# %%
j =  []
columns = d.drop(columns="values").columns.tolist()
for i in range(d.shape[0]):
    leftside = pd.DataFrame(d.iloc[i]).T
    rightside = pd.DataFrame(d.iloc[i]["values"])
    for c in columns:
        rightside.loc[:,c] = leftside[c].values
    j.append(rightside)

# %%
dj = pd.concat(j)
dj.to_csv("airquality_index_2015_2019.csv", index=False)

# %% [markdown]
# # Weather data from frost.met.no

# %% [markdown]
# The [frost API](https://frost.met.no/index2.html) provides free access to MET Norway's archive of historical weather and climate data

# %% [markdown]
# ## [Examples](https://frost.met.no/ex_userquest) from docs

# %% [markdown]
# ## Find station from location name

# %%
# Obtained for free for Hackathon
client_id = "6d9ad2eb-f1dd-4164-8c16-451d98f49116"
client_secret = "6e43d276-c0d2-4ae1-91d9-cc20adf65324"

# %%
location = "Trondheim*" 
src_endpoint = 'https://frost.met.no/sources/v0.jsonld'
parameters = {
    'types': 'SensorSystem',
    'name': location,
}

r = requests.get(src_endpoint, parameters, auth=(client_id,''))
# Extract JSON data
json = r.json()
json
# Out:
# {'@context': 'https://frost.met.no/schema',
#  '@type': 'SourceResponse',
#  'apiVersion': 'v0',
#  'license': 'https://creativecommons.org/licenses/by/3.0/no/',
#  'createdAt': '2019-06-24T05:19:25Z',
#  'queryTime': 2.751,
#  'currentItemCount': 5,
#  'itemsPerPage': 5,
#  'offset': 0,
#  'totalItemCount': 5,
#  'currentLink': 'https://frost.met.no/sources/v0.jsonld?types=SensorSystem&name=Trondheim%2A',
#  'data': [{'@type': 'SensorSystem',
#    'id': 'SN68230',
#    'name': 'TRONDHEIM - RISVOLLAN',
#    'shortName': 'Risvollan',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4228, 63.3987],
#     'nearest': False},
#    'masl': 84,
#    'validFrom': '1986-12-11T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['NVE'],
#    'externalIds': ['123.38'],
#    'wigosId': '0-578-0-68230'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68173',
#    'name': 'TRONDHEIM - GLØSHAUGEN',
#    'shortName': 'Gløshaugen',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4072, 63.4153],
#     'nearest': False},
#    'masl': 60,
#    'validFrom': '2015-12-15T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['MET.NO'],
#    'externalIds': ['10.249.0.58'],
#    'wigosId': '0-578-0-68173'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68860',
#    'name': 'TRONDHEIM - VOLL',
#    'shortName': 'Trondheim',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'wmoId': 1257,
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4538, 63.4107],
#     'nearest': False},
#    'masl': 127,
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['MET.NO'],
#    'externalIds': ['01257', '10.249.0.160'],
#    'wigosId': '0-20000-0-01257'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68863',
#    'name': 'TRONDHEIM - VOLL PLU',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4535, 63.4107],
#     'nearest': False},
#    'masl': 127,
#    'validFrom': '2000-01-01T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['TRONDHEIM KOMMUNE'],
#    'wigosId': '0-578-0-68863'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68010',
#    'name': 'TRONDHEIM - HØVRINGEN',
#    'shortName': 'Høvringen ',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.3364, 63.4465],
#     'nearest': False},
#    'masl': 44,
#    'validFrom': '2016-05-01T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['SINTEF BYGGFORSK'],
#    'wigosId': '0-578-0-68010'}]}

# %%
json
# Out:
# {'@context': 'https://frost.met.no/schema',
#  '@type': 'SourceResponse',
#  'apiVersion': 'v0',
#  'license': 'https://creativecommons.org/licenses/by/3.0/no/',
#  'createdAt': '2019-06-24T05:18:38Z',
#  'queryTime': 2.007,
#  'currentItemCount': 5,
#  'itemsPerPage': 5,
#  'offset': 0,
#  'totalItemCount': 5,
#  'currentLink': 'https://frost.met.no/sources/v0.jsonld?types=SensorSystem&name=Trondheim%2A',
#  'data': [{'@type': 'SensorSystem',
#    'id': 'SN68230',
#    'name': 'TRONDHEIM - RISVOLLAN',
#    'shortName': 'Risvollan',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4228, 63.3987],
#     'nearest': False},
#    'masl': 84,
#    'validFrom': '1986-12-11T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['NVE'],
#    'externalIds': ['123.38'],
#    'wigosId': '0-578-0-68230'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68173',
#    'name': 'TRONDHEIM - GLØSHAUGEN',
#    'shortName': 'Gløshaugen',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4072, 63.4153],
#     'nearest': False},
#    'masl': 60,
#    'validFrom': '2015-12-15T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['MET.NO'],
#    'externalIds': ['10.249.0.58'],
#    'wigosId': '0-578-0-68173'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68860',
#    'name': 'TRONDHEIM - VOLL',
#    'shortName': 'Trondheim',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'wmoId': 1257,
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4538, 63.4107],
#     'nearest': False},
#    'masl': 127,
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['MET.NO'],
#    'externalIds': ['01257', '10.249.0.160'],
#    'wigosId': '0-20000-0-01257'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68863',
#    'name': 'TRONDHEIM - VOLL PLU',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.4535, 63.4107],
#     'nearest': False},
#    'masl': 127,
#    'validFrom': '2000-01-01T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['TRONDHEIM KOMMUNE'],
#    'wigosId': '0-578-0-68863'},
#   {'@type': 'SensorSystem',
#    'id': 'SN68010',
#    'name': 'TRONDHEIM - HØVRINGEN',
#    'shortName': 'Høvringen ',
#    'country': 'Norge',
#    'countryCode': 'NO',
#    'geometry': {'@type': 'Point',
#     'coordinates': [10.3364, 63.4465],
#     'nearest': False},
#    'masl': 44,
#    'validFrom': '2016-05-01T00:00:00.000Z',
#    'county': 'TRØNDELAG',
#    'countyId': 50,
#    'municipality': 'TRONDHEIM',
#    'municipalityId': 5001,
#    'stationHolders': ['SINTEF BYGGFORSK'],
#    'wigosId': '0-578-0-68010'}]}

# %% [markdown]
# ## Request available timeSeries from station

# %%
station = 'SN68860' # Gløshaugen

# %%
src_endpoint = 'https://frost.met.no/observations/availableTimeSeries/v0.jsonld'
parameters = {
    'sources': station,
    'referencetime': '2019-06-01',
}

r = requests.get(src_endpoint, parameters, auth=(client_id,''))
# Extract JSON data
json = r.json()
json
# Out:
# {'@context': 'https://frost.met.no/schema',
#  '@type': 'ObservationTimeSeriesResponse',
#  'apiVersion': 'v0',
#  'license': 'https://creativecommons.org/licenses/by/3.0/no/',
#  'createdAt': '2019-06-24T05:23:18Z',
#  'queryTime': 0.095,
#  'currentItemCount': 136,
#  'itemsPerPage': 136,
#  'offset': 0,
#  'totalItemCount': 136,
#  'currentLink': 'https://frost.met.no/observations/availableTimeSeries/v0.jsonld?sources=SN68860&referencetime=2019-06-01',
#  'data': [{'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'over_time(humidity_mixing_ratio P1D)',
#    'unit': 'gr/kg',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=over_time(humidity_mixing_ratio P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1957-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_pressure_at_sea_level P1D)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1957-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_pressure_at_sea_level P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1956-12-31T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1956-12-31T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature P1D)&timeoffsets=PT6H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(wind_speed P1M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(wind_speed P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1997-07-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean(wind_speed_of_gust P1D)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1997-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(wind_speed_of_gust P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_temperature PT1H)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_temperature PT1H)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'max(relative_humidity P1D)',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(relative_humidity P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'specific_humidity',
#    'unit': 'gr/kg',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=specific_humidity&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '2005-07-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean_k(air_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean_k(air_temperature P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1944-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'min(surface_air_pressure P1M)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1944-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(surface_air_pressure P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'integral_of_excess(mean(air_temperature P1D) P1D 0.0)',
#    'unit': 'degree-day',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=integral_of_excess(mean(air_temperature P1D) P1D 0.0)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1926-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P3M',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_temperature P3M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1926-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_temperature P3M)&timeoffsets=PT18H&timeresolutions=P3M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'max(wind_speed P1D)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(wind_speed P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount PT1H)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount PT1H)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean(wind_speed P1D)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(wind_speed P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-06-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P3M',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount_anomaly P3M 1961_1990)',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-06-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount_anomaly P3M 1961_1990)&timeoffsets=PT6H&timeresolutions=P3M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1926-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_temperature P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1926-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_temperature P1M)&timeoffsets=PT18H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'min(max(wind_speed P1D) P1M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(max(wind_speed P1D) P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'max(wind_speed PT1H)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(wind_speed PT1H)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'air_pressure_at_sea_level_qnh',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=air_pressure_at_sea_level_qnh&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P3M',
#    'timeSeriesId': 0,
#    'elementId': 'integral_of_deficit(mean(air_temperature P1D) P3M 17.0)',
#    'unit': 'degree-day',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=integral_of_deficit(mean(air_temperature P1D) P3M 17.0)&timeoffsets=PT0H&timeresolutions=P3M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1957-01-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1957-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature P1M)&timeoffsets=PT6H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'integral_of_deficit(mean(air_temperature P1D) P1M 17.0)',
#    'unit': 'degree-day',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=integral_of_deficit(mean(air_temperature P1D) P1M 17.0)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P3M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(cloud_area_fraction P3M)',
#    'unit': 'octas',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(cloud_area_fraction P3M)&timeoffsets=PT0H&timeresolutions=P3M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-06-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P6M',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount_anomaly P6M 1961_1990)',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-06-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount_anomaly P6M 1961_1990)&timeoffsets=PT6H&timeresolutions=P6M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'min(relative_humidity P1D)',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(relative_humidity P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature_anomaly P1M 1961_1990)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature_anomaly P1M 1961_1990)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1997-08-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(wind_speed_of_gust P1M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1997-08-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(wind_speed_of_gust P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1922-12-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'best_estimate_mean(air_temperature P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1922-12-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=best_estimate_mean(air_temperature P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'integral_of_excess(mean(air_temperature P1D) P1D 5.0)',
#    'unit': 'degree-day',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=integral_of_excess(mean(air_temperature P1D) P1D 5.0)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean(max(wind_speed PT1H) P1D)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(max(wind_speed PT1H) P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2016-03-10T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT10M',
#    'timeSeriesId': 0,
#    'elementId': 'sum(duration_of_precipitation PT10M)',
#    'unit': 'minutes',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2016-03-10T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(duration_of_precipitation PT10M)&timeoffsets=PT0H&timeresolutions=PT10M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'max_wind_speed(wind_from_direction PT1H)',
#    'unit': 'degrees',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max_wind_speed(wind_from_direction PT1H)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'relative_humidity',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=relative_humidity&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'min(wind_speed P1M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(wind_speed P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1997-07-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'min(wind_speed_of_gust P1D)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1997-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(wind_speed_of_gust P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'integral_of_deficit(mean(air_temperature PT1H) P1D 17.0)',
#    'unit': 'degree-day',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=integral_of_deficit(mean(air_temperature PT1H) P1D 17.0)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1945-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'over_time(time_of_maximum_air_temperature P1M)',
#    'unit': 'Date',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1945-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=over_time(time_of_maximum_air_temperature P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'min(air_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(air_temperature P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '2005-10-26T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'min(air_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-10-26T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(air_temperature P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'min(relative_humidity P1M)',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(relative_humidity P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'min(max(wind_speed PT1H) P1D)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(max(wind_speed PT1H) P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2005-07-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean(dew_point_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(dew_point_temperature P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1944-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'max(surface_air_pressure P1M)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1944-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(surface_air_pressure P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1944-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(surface_air_pressure P1M)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1944-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(surface_air_pressure P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1944-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'max(surface_air_pressure P1D)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1944-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(surface_air_pressure P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'max(wind_speed P1M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(wind_speed P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1997-08-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'max(wind_speed_of_gust P1M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1997-08-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(wind_speed_of_gust P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1Y',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature P1Y)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature P1Y)&timeoffsets=PT0H&timeresolutions=P1Y&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-06-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P3M',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount P3M)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-06-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount P3M)&timeoffsets=PT6H&timeresolutions=P3M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1922-12-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'best_estimate_mean(air_temperature_anomaly P1M 1961_1990)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1922-12-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=best_estimate_mean(air_temperature_anomaly P1M 1961_1990)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '2016-03-10T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT10M',
#    'timeSeriesId': 0,
#    'elementId': 'max(wind_speed_of_gust PT10M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2016-03-10T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(wind_speed_of_gust PT10M)&timeoffsets=PT0H&timeresolutions=PT10M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2003-08-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'dew_point_temperature',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2003-08-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=dew_point_temperature&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1940-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(max(air_temperature P1D) P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1940-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(max(air_temperature P1D) P1M)&timeoffsets=PT18H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(water_vapor_partial_pressure_in_air P1M)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(water_vapor_partial_pressure_in_air P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'accumulated(precipitation_amount)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=accumulated(precipitation_amount)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2019-03-06T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT10M',
#    'timeSeriesId': 0,
#    'elementId': 'accumulated(precipitation_amount)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2019-03-06T00:00:00.000Z/9999-12-31T23:59:59Z&elements=accumulated(precipitation_amount)&timeoffsets=PT0H&timeresolutions=PT10M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2005-07-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'over_time(time_of_maximum_wind_speed P1M)',
#    'unit': 'Date',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=over_time(time_of_maximum_wind_speed P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1922-12-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P3M',
#    'timeSeriesId': 0,
#    'elementId': 'best_estimate_mean(air_temperature_anomaly P3M 1961_1990)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1922-12-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=best_estimate_mean(air_temperature_anomaly P3M 1961_1990)&timeoffsets=PT0H&timeresolutions=P3M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'over_time(tendency_of_surface_air_pressure PT1H)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=over_time(tendency_of_surface_air_pressure PT1H)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P6M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature_anomaly P6M 1961_1990)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature_anomaly P6M 1961_1990)&timeoffsets=PT0H&timeresolutions=P6M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1926-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P6M',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_temperature P6M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1926-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_temperature P6M)&timeoffsets=PT18H&timeresolutions=P6M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(humidity_mixing_ratio P1M)',
#    'unit': 'gr/kg',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(humidity_mixing_ratio P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(min(air_temperature P1D) P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(min(air_temperature P1D) P1M)&timeoffsets=PT18H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-06-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P1Y',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount_anomaly P1Y 1961_1990)',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-06-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount_anomaly P1Y 1961_1990)&timeoffsets=PT6H&timeresolutions=P1Y&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1922-12-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1Y',
#    'timeSeriesId': 0,
#    'elementId': 'best_estimate_mean(air_temperature P1Y)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1922-12-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=best_estimate_mean(air_temperature P1Y)&timeoffsets=PT18H&timeresolutions=P1Y&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(relative_humidity P1M)',
#    'unit': 'percent',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(relative_humidity P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1957-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'min(air_pressure_at_sea_level P1M)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1957-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(air_pressure_at_sea_level P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-02T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount P1D)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-02T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount P1D)&timeoffsets=PT6H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount P1D)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2005-07-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'PT12H',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount PT12H)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount PT12H)&timeoffsets=PT6H&timeresolutions=PT12H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'max(wind_speed_of_gust PT1H)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(wind_speed_of_gust PT1H)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'air_pressure_at_sea_level',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=air_pressure_at_sea_level&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1Y',
# ...
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(water_vapor_partial_pressure_in_air P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-06-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P6M',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount P6M)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-06-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount P6M)&timeoffsets=PT6H&timeresolutions=P6M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P6M',
#    'timeSeriesId': 0,
#    'elementId': 'min(air_temperature P6M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(air_temperature P6M)&timeoffsets=PT18H&timeresolutions=P6M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2015-09-18T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'over_time(time_of_maximum_wind_speed_of_gust PT1H)',
#    'unit': 'time',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2015-09-18T00:00:00.000Z/9999-12-31T23:59:59Z&elements=over_time(time_of_maximum_wind_speed_of_gust PT1H)&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1940-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1940-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_temperature P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '2005-10-26T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_temperature P1D)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-10-26T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_temperature P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1Y',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature_anomaly P1Y 1961_1990)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature_anomaly P1Y 1961_1990)&timeoffsets=PT0H&timeresolutions=P1Y&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1957-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_pressure_at_sea_level P1D)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1957-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_pressure_at_sea_level P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-31T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount P30D)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-31T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount P30D)&timeoffsets=PT6H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(max(wind_speed P1D) P1M)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(max(wind_speed P1D) P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1957-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'min(air_pressure_at_sea_level P1D)',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1957-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(air_pressure_at_sea_level P1D)&timeoffsets=PT0H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P3M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature_anomaly P3M 1961_1990)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature_anomaly P3M 1961_1990)&timeoffsets=PT0H&timeresolutions=P3M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1951-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1D',
#    'timeSeriesId': 0,
#    'elementId': 'max(max(wind_speed PT1H) P1D)',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1951-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(max(wind_speed PT1H) P1D)&timeoffsets=PT18H&timeresolutions=P1D&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '2005-07-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(dew_point_temperature P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(dew_point_temperature P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P6M',
#    'timeSeriesId': 0,
#    'elementId': 'mean(air_temperature P6M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean(air_temperature P6M)&timeoffsets=PT0H&timeresolutions=P6M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-02-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount P1M)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-02-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount P1M)&timeoffsets=PT6H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT18H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'sum(precipitation_amount P1M)',
#    'unit': 'mm',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=sum(precipitation_amount P1M)&timeoffsets=PT18H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'over_time(time_of_minimum_air_temperature P1M)',
#    'unit': 'Date',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=over_time(time_of_minimum_air_temperature P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'surface_air_pressure',
#    'unit': 'hPa',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=surface_air_pressure&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '1996-09-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT1H',
#    'timeSeriesId': 0,
#    'elementId': 'wind_speed',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1996-09-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=wind_speed&timeoffsets=PT0H&timeresolutions=PT1H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#    'validFrom': '2016-03-10T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'PT10M',
#    'timeSeriesId': 0,
#    'elementId': 'wind_speed',
#    'unit': 'm/s',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2016-03-10T00:00:00.000Z/9999-12-31T23:59:59Z&elements=wind_speed&timeoffsets=PT0H&timeresolutions=PT10M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=10.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '2005-07-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1M',
#    'timeSeriesId': 0,
#    'elementId': 'mean_k(air_temperature P1M)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-07-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=mean_k(air_temperature P1M)&timeoffsets=PT0H&timeresolutions=P1M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '2005-01-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'PT12H',
#    'timeSeriesId': 0,
#    'elementId': 'min(air_temperature PT12H)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=min(air_temperature PT12H)&timeoffsets=PT6H&timeresolutions=PT12H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'validFrom': '1922-12-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P1Y',
#    'timeSeriesId': 0,
#    'elementId': 'best_estimate_mean(air_temperature_anomaly P1Y 1961_1990)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1922-12-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=best_estimate_mean(air_temperature_anomaly P1Y 1961_1990)&timeoffsets=PT0H&timeresolutions=P1Y&timeseriesids=0&performancecategories=A&exposurecategories=1'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '2005-01-01T00:00:00.000Z',
#    'timeOffset': 'PT6H',
#    'timeResolution': 'PT12H',
#    'timeSeriesId': 0,
#    'elementId': 'max(air_temperature PT12H)',
#    'unit': 'degC',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=2005-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=max(air_temperature PT12H)&timeoffsets=PT6H&timeresolutions=PT12H&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'},
#   {'sourceId': 'SN68860:0',
#    'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#    'validFrom': '1923-01-01T00:00:00.000Z',
#    'timeOffset': 'PT0H',
#    'timeResolution': 'P6M',
#    'timeSeriesId': 0,
#    'elementId': 'integral_of_deficit(mean(air_temperature P1D) P6M 17.0)',
#    'unit': 'degree-day',
#    'performanceCategory': 'A',
#    'exposureCategory': '1',
#    'status': 'Authoritative',
#    'uri': 'https://frost.met.noobservations/v0.jsonld?sources=SN68860:0&referencetime=1923-01-01T00:00:00.000Z/9999-12-31T23:59:59Z&elements=integral_of_deficit(mean(air_temperature P1D) P6M 17.0)&timeoffsets=PT0H&timeresolutions=P6M&timeseriesids=0&performancecategories=A&exposurecategories=1&levels=2.0'}]}

# %%
# Get mean air temperature observations for one station for one year

# %%
src_endpoint = 'https://frost.met.no/observations/v0.jsonld'
element_list = ['mean(air_temperature P1D)', 'max(air_pressure_at_sea_level P1D)','sum(precipitation_amount P1D)', 'mean(wind_speed P1D)']
parameters = {
    'sources': station,
    'referencetime': '2016-01-01T00:00:00.000Z/2016-12-31T23:59:59Z',
    'elements': ",".join(element_list),
    'timeoffsets': ",".join(['PT0H', 'PT0H', 'PT6H'])
}
#
r = requests.get(src_endpoint, parameters, auth=(client_id,''))
# Extract JSON data
json = r.json()
json
# Out:
# {'@context': 'https://frost.met.no/schema',
#  '@type': 'ObservationResponse',
#  'apiVersion': 'v0',
#  'license': 'https://creativecommons.org/licenses/by/3.0/no/',
#  'createdAt': '2019-06-24T06:12:47Z',
#  'queryTime': 0.34,
#  'currentItemCount': 366,
#  'itemsPerPage': 366,
#  'offset': 0,
#  'totalItemCount': 366,
#  'currentLink': 'https://frost.met.no/observations/v0.jsonld?sources=SN68860&referencetime=2016-01-01T00%3A00%3A00.000Z%2F2016-12-31T23%3A59%3A59Z&elements=mean%28air_temperature+P1D%29%2Cmax%28air_pressure_at_sea_level+P1D%29%2Csum%28precipitation_amount+P1D%29%2Cmean%28wind_speed+P1D%29&timeoffsets=PT0H%2CPT0H%2CPT6H',
#  'data': [{'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-01T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 4.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 4.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1028,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-02T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 0.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 3.7,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1032.3,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 4.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-03T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -5.9,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -2.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1030,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-04T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -8.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -6.8,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1012,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-05T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -8.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -8.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1013.2,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-06T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -10.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -9.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1014,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-07T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -10.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -9.5,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1012.5,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3.5,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-08T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -16.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -12.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1010.9,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0.2,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-09T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -12.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -15.8,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1012.2,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-10T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -6.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -10.8,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1009.4,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-11T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -1.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -4.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 997.3,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-12T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -5.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -2.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1005.6,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.9,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-13T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -7.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -5.8,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1009.1,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.3,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-14T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -9.9,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -8.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1010.9,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-15T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -12.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -10.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1021.4,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-16T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -7.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -12,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1024.9,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0.2,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.5,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-17T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -6.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1024.5,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0.1,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 4.6,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-18T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -1.9,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -1.8,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1008.9,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 7.1,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3.3,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-19T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -2.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -1.9,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1009.8,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 4.2,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-20T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -1.8,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -2.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1017.2,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 4,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-21T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -3.5,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -1.7,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1022.3,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 4.6,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-22T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -6.5,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -4.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1022.5,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0.1,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-23T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -1.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -5.5,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1017.1,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 1.8,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.3,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-24T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': -0.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -1.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1016.7,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 1.5,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1.6,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-25T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 0.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': -0.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1013.7,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 2.6,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-26T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 3.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 1.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 997.8,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 5.5,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 3.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-27T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 2.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 3.5,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 990.7,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 1.1,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.4,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-28T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 0.7,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 1.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 994.7,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 1.5,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.5,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-29T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 4.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 1.5,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 992.9,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0.7,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 6.5,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-01-30T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 1.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 4.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
# ...
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 3.9,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1000.3,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 0,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.7,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-23T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 1.5,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1006.6,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 1.7,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 5.2,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-24T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 2.4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 2.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 985.9,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 7.4,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 4.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-25T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 3.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 2.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 990.4,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 16.8,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 4.1,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-26T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 1.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 2.9,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 991.4,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 15,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 5,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-27T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 1.8,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 1.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1029.7,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 4.8,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 4.4,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-28T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 1.6,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1030.2,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 2.9,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.5,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-29T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 5.2,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 4,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1019,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 10.1,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 2.3,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-30T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 6.1,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 5.7,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1010.4,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 12.5,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 4.8,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]},
#   {'sourceId': 'SN68860:0',
#    'referenceTime': '2016-12-31T00:00:00.000Z',
#    'observations': [{'elementId': 'mean(air_temperature P1D)',
#      'value': 3.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 0},
#     {'elementId': 'mean(air_temperature P1D)',
#      'value': 5.3,
#      'unit': 'degC',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 2},
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'max(air_pressure_at_sea_level P1D)',
#      'value': 1001.6,
#      'unit': 'hPa',
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'sum(precipitation_amount P1D)',
#      'value': 6.9,
#      'unit': 'mm',
#      'timeOffset': 'PT6H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2},
#     {'elementId': 'mean(wind_speed P1D)',
#      'value': 5.4,
#      'unit': 'm/s',
#      'level': {'levelType': 'height_above_ground', 'unit': 'm', 'value': 10},
#      'timeOffset': 'PT0H',
#      'timeResolution': 'P1D',
#      'timeSeriesId': 0,
#      'performanceCategory': 'A',
#      'exposureCategory': '1',
#      'qualityCode': 2}]}]}

# %% [markdown]
# ## Read into pandas DataFrame

# %%
df_weather = pd.DataFrame.from_records(json["data"])

# %%
# Extract values
for i,e in enumerate(df_weather["observations"][0]):
    df_weather[e['elementId']+"_"+e['timeOffset']] = df_weather["observations"].apply(lambda x: x[i]["value"])

# %%
df_weather.head()
# Out:
#                                         observations  \
# 0  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 1  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 2  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 3  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 4  [{'elementId': 'mean(air_temperature P1D)', 'v...
#
#               referenceTime   sourceId  mean(air_temperature P1D)_PT0H  \
# 0  2018-01-01T00:00:00.000Z  SN68860:0                             0.9
# 1  2018-01-02T00:00:00.000Z  SN68860:0                             0.1
# 2  2018-01-03T00:00:00.000Z  SN68860:0                            -3.3
# 3  2018-01-04T00:00:00.000Z  SN68860:0                            -1.6
# 4  2018-01-05T00:00:00.000Z  SN68860:0                            -3.4
#
#    mean(air_temperature P1D)_PT6H  max(air_pressure_at_sea_level P1D)_PT0H  \
# 0                            -2.9                                    986.3
# 1                             0.8                                    996.2
# 2                            -1.4                                    996.1
# 3                            -2.5                                    999.3
# 4                            -1.7                                   1003.6
#
#    sum(precipitation_amount P1D)_PT6H
# 0                                 0.0
# 1                                 0.7
# 2                                 0.2
# 3                                 0.0
# 4                                 0.0

# %%
df_weather.head(20)
# Out:
#                                          observations  \
# 0   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 1   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 2   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 3   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 4   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 5   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 6   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 7   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 8   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 9   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 10  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 11  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 12  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 13  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 14  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 15  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 16  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 17  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 18  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 19  [{'elementId': 'mean(air_temperature P1D)', 'v...
#
#                referenceTime   sourceId  mean(air_temperature P1D)_PT0H  \
# 0   2018-01-01T00:00:00.000Z  SN68860:0                             0.9
# 1   2018-01-02T00:00:00.000Z  SN68860:0                             0.1
# 2   2018-01-03T00:00:00.000Z  SN68860:0                            -3.3
# 3   2018-01-04T00:00:00.000Z  SN68860:0                            -1.6
# 4   2018-01-05T00:00:00.000Z  SN68860:0                            -3.4
# 5   2018-01-06T00:00:00.000Z  SN68860:0                            -3.4
# 6   2018-01-07T00:00:00.000Z  SN68860:0                            -1.1
# 7   2018-01-08T00:00:00.000Z  SN68860:0                             0.9
# 8   2018-01-09T00:00:00.000Z  SN68860:0                            -2.4
# 9   2018-01-10T00:00:00.000Z  SN68860:0                            -4.0
# 10  2018-01-11T00:00:00.000Z  SN68860:0                            -0.5
# 11  2018-01-12T00:00:00.000Z  SN68860:0                            -0.5
# 12  2018-01-13T00:00:00.000Z  SN68860:0                            -4.3
# 13  2018-01-14T00:00:00.000Z  SN68860:0                            -4.6
# 14  2018-01-15T00:00:00.000Z  SN68860:0                            -1.4
# 15  2018-01-16T00:00:00.000Z  SN68860:0                            -0.3
# 16  2018-01-17T00:00:00.000Z  SN68860:0                            -0.7
# 17  2018-01-18T00:00:00.000Z  SN68860:0                            -3.6
# 18  2018-01-19T00:00:00.000Z  SN68860:0                            -6.1
# 19  2018-01-20T00:00:00.000Z  SN68860:0                            -5.4
#
#     mean(air_temperature P1D)_PT6H  max(air_pressure_at_sea_level P1D)_PT0H  \
# 0                             -2.9                                    986.3
# 1                              0.8                                    996.2
# 2                             -1.4                                    996.1
# 3                             -2.5                                    999.3
# 4                             -1.7                                   1003.6
# 5                             -3.9                                   1017.4
# 6                             -3.0                                   1022.8
# 7                             -0.4                                   1027.5
# 8                              0.7                                   1027.6
# 9                             -3.6                                   1021.5
# 10                            -3.1                                   1030.0
# 11                            -0.1                                   1034.0
# 12                            -1.4                                   1033.2
# 13                            -5.2                                   1026.9
# 14                            -3.7                                   1004.2
# 15                            -0.8                                    979.7
# 16                            -0.6                                    990.9
# 17                            -1.1                                    994.6
# 18                            -4.8                                   1000.4
# 19                            -6.3                                   1007.7
#
#     sum(precipitation_amount P1D)_PT6H
# 0                                  0.0
# 1                                  0.7
# 2                                  0.2
# 3                                  0.0
# 4                                  0.0
# 5                                  0.0
# 6                                  5.7
# 7                                  6.1
# 8                                  2.0
# 9                                  0.0
# 10                                 0.0
# 11                                 0.0
# 12                                 0.0
# 13                                 0.0
# 14                                 0.0
# 15                                 0.0
# 16                                 0.0
# 17                                 0.0
# 18                                 0.0
# 19                                 0.0

# %%
dfs = []
for year in [str(y) for y in range(2016,2019)]:
    src_endpoint = 'https://frost.met.no/observations/v0.jsonld'
    #element_list = ['mean(air_temperature P1D)', 'max(air_pressure_at_sea_level P1D)','sum(precipitation_amount P1D)']
    parameters = {
        'sources': station,
        'referencetime': f'{year}-01-01T00:00:00.000Z/{year}-12-31T23:59:59Z',
        'elements': ",".join(element_list),
        'timeoffsets': ",".join(['PT0H', 'PT0H', 'PT6H'])
    }
    #
    r = requests.get(src_endpoint, parameters, auth=(client_id,''))
    # Extract JSON data
    json = r.json()
    json
    df_weather = pd.DataFrame.from_records(json["data"])
    # Extract values
    for i,e in enumerate(df_weather["observations"][0]):
        df_weather[e['elementId']+"_"+e['timeOffset']] = df_weather["observations"].apply(lambda x: x[i]["value"])
    dfs.append(df_weather)

# %%
df_tot = pd.concat(dfs)

# %%
df_tot.shape
# Out:
# (1096, 8)

# %%
df_tot.sample(10)
# Out:
#                                           observations  \
# 292  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 361  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 341  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 228  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 184  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 88   [{'elementId': 'mean(air_temperature P1D)', 'v...
# 317  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 196  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 163  [{'elementId': 'mean(air_temperature P1D)', 'v...
# 132  [{'elementId': 'mean(air_temperature P1D)', 'v...
#
#                 referenceTime   sourceId  mean(air_temperature P1D)_PT0H  \
# 292  2017-10-20T00:00:00.000Z  SN68860:0                             5.9
# 361  2018-12-28T00:00:00.000Z  SN68860:0                             3.9
# 341  2016-12-07T00:00:00.000Z  SN68860:0                             0.5
# 228  2016-08-16T00:00:00.000Z  SN68860:0                            13.3
# 184  2018-07-04T00:00:00.000Z  SN68860:0                            13.2
# 88   2016-03-29T00:00:00.000Z  SN68860:0                             7.2
# 317  2018-11-14T00:00:00.000Z  SN68860:0                             2.7
# 196  2018-07-16T00:00:00.000Z  SN68860:0                            20.7
# 163  2016-06-12T00:00:00.000Z  SN68860:0                            10.5
# 132  2017-05-13T00:00:00.000Z  SN68860:0                            10.2
#
#      mean(air_temperature P1D)_PT6H  max(air_pressure_at_sea_level P1D)_PT0H  \
# 292                             3.2                                   1018.3
# 361                             4.6                                   1016.4
# 341                             0.8                                   1020.2
# 228                            11.2                                   1025.6
# 184                            13.0                                   1018.9
# 88                              8.1                                    997.7
# 317                             2.8                                   1015.8
# 196                            18.9                                   1017.2
# 163                            11.5                                   1016.9
# 132                             8.6                                   1015.2
#
#      sum(precipitation_amount P1D)_PT6H  mean(wind_speed P1D)_PT0H
# 292                                 0.1                        2.3
# 361                                 2.5                        2.9
# 341                                 0.1                        1.5
# 228                                 0.2                        1.4
# 184                                 0.1                        2.7
# 88                                  0.0                        4.1
# 317                                 0.0                        1.0
# 196                                 0.0                        2.1
# 163                                 0.0                        2.2
# 132                                 0.0                        2.1
